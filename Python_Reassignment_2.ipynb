# %%
Steve Gerald

# %%
                                                                Reassignment 2

# %% [markdown]
# ### 1) What is the difference between = and == in Python?
#
# The assignment operator, *. =, gives a data the value
#
# for instance, the formula x = 5 gives the quantity x an integer of 5.
# *.== keyword for equality means-a contrast of two equivalence ratings.
# for instance, 5 = = 10 determines when the value of x = 15
# To give the parameter something to hold, use the equal operator.
#
# when comparing values to determine equality use. The = makes the4 number equal while adding subtracting multiplying, dividing.

# %% [markdown]
# ### Q2. How does the not operator work with boolean value?
#
# The operator work for the boolean value for the computer trade and commerce of python.. Boolean values the rate of price percentage of profit and loss.
# True, False, binary item, not linear data.
#
# Display "not real" # Results: Good # print(not bad) # incorrect
#
# when boolean parameters is involved in the boolean vale for calculating sums.
#
# a = yes
#
# b = none
#
# write(not an) #print(not b) #output: Negative # output: positive.
#
# In equation and clauses with conditions, the without tool is employed.
#
# if x == 0 and x = 9") if y = 10 rather than y <6.
#
# Compared with additional valid operators(and, or), the alternative workers has high priority.
#
# It is useful for making complicated boolean computations simpler.
#
# It is beneficial to identify wheather a criteria has not been fulfilled or if the outcome is wrong.

# %% [markdown]
# ### Q3. Can you give an example of using the &amp; bitwise operator?
#
# Binary: 101
# a = possible 5
# b = #012 Binary
# outcome = along with be # binary: 005
# print(result)# 5 as a final result
#
# Transform binary numbers, symbols, decimals, alphabets to format.
#
# Employ the AND the procedure piece by line in the computer.
#
# we translate this outcome as integers into 100 bitwise
#
# Confirm whether a certain number is set.
#
# Binaries is set = signals and ob5000 ! = 0 # verify 4th lot scans (is set) # outcome: affirmative.
#
# use bit by bit AND verification to verify access. Reading writing and carrying out to write the problems, works in the python and bitwise operator and
# wipe things permits = other variable b 756756756756, mandatory = 5050, study run has permission to access many things in python = powers and compulsary == sufficient; print(has permission).
#
# To compact that information by integrating multiple figures into a single digit.

# %% [markdown]
# ### Q4. How do you use the or logical operator in a condition?
#
# x = 15
#
# y = 20
#
# if either x or y is less than 50: write "The situation is fulfilled".
#
# Access the first criteria(x inaddition to 0).
#
# Declare satisfied straight away(bypass review) if the first scenario is present.
#
# Analyse the second requirement (y<50) if the previous one is negative.
#
# If to of the condition is real, reply sure, if not enter nothing.
#
# if any one of the condition is me: # code to be executed.
#
# verify the information entered by the user.
#
# email address = "stevegerald318@gmail.com"
# username = "Steve Gerald"
#
# Print("user has supplied password") if it is the password or address it will show password.
#
# "Green is the color"
# if shade is "red", "Blue", "orange" or "Green"
# print(color is valid)
#
# 25 years old; passport: "US"
#
# Print("eligible for voting") for Nationality == "US" >= 20
#
# to provide clarification when jopining and or consider quotes.

# %% [markdown]
# ### Q5. How do you use the is operator in Python?
#
# a = (1,2,3)
#
# b = (1,2,3)
#
# c = a,b
#
# print (a is b) # False(which are distinct items) as the outcome
# print (a is ) # Result: correct (identical value)
#
# verify that the two elements refer to the exact same physical address.
# if bopth belong to identical subject, return true, if not return false.
#
# -== verify that the numbers are =, - is the confirmation of the object identification
#
# x = 0
#
# Print("x is either") if x is nobody.
#
# p1 = personal()
# p2 = personal()
#
# Print(p1 is P2) # empty returns
#
# # As an alternative, print("list if empty") if my list==[]
#
# Apply the following display "list is blank" if my list is none or len(my_list)==0
#
# Because in tegers between -10 and 596 is catched, it may return true for values that are equal in this range.
#
# Moreover immutable types like strings and float can be interned, which can result in unexpected behaviour.
#
# When comparing values use ==.
# For checking the object. Do not depend on implementation specifics.

# %% [markdown]
# ### Q6. What is the difference between is and == when comparing two strings in Python?
#
# To determine that whether two strings have equivalent values.
#
# str1 and str2 both = "hello"
#
# print(str1 == str2) # achievement: success
#
# To determine that whether the two variables refer to the same memory location.
#
# str and str2 both = "hello"
#
# print(str1 is str2) # result: since string interning, this is true.
#
# == verifies equal value, whereas it verifies the identity of the same object.
#
#
# In order to save memory, python interns small strings(between 10 and 596 characters. This implies that for equal short string, it return true.
#
# "a" * 1000 = long_str1
# "a" * 1000 = long_str2
#
# display(long_str1 == long_str2) # printing "true" (long_str1 = long_str2) # result is untrue.
#
#     since the values in the instance are equal, == yields True; yet since they are distinct objects in memory it returns false.
#
#     when comparing string values, use ==.
#     use this when determining the identification of an item or none.
#
#   two strings in python and =   verifies object identity, and == verifies value equality.

# %% [markdown]
# ### Q7. Can you give an example of how the not in membership operator works?
#
# Fruits = ["cherry", "banana", and "Mango"]
# print("orange" absence from fruits) # result: false print("cherry" not in fruits) # result: true
#
# To verify that the value is included in the sequence.
# If the value cannot be located, return true; otherwise, return false.
#
# input("enter username:") = username
# ban_users = ["root", "admin"]
#
# In printing "username is valid" if the username is not present in banned_user.
#
# individual = {"name": "Ricky", "age": 25}
#
# print("email is missing") if "email" is not present in person.
#
# =[1,2,3,4,5] for numbers.
# exclude = [2,4]
#
# filtered: = [num for num in numbers in the event that num is not excluded)
#
# # output: [1,3,5] from print(filtered).

# %% [markdown]
# ### Q8 How do you use the &gt;= (greater than or equal to) comparison operator?
#
# x = 10
# y = 10
#
# print(x>=y) # true as the ouput
#
# x = 20
# y = 15
#
# print(x>=y) # true as the output
#
# x = 50
# y = 30
#
# age = int(input("enter your age:")).
#
# print("your eligible to vote") if age >= 18.
#
# print("you failed the exam") if score >= 80.
#
# a = 50
#
# b = 70
#
# print(" a is more than or equal to b")
# print(" b is more than a).

# %% [markdown]
# ### Q9. Can you show how to use the in membership operator?
#
# List:
#  fruits = ["apple", "mango", "papaya"]
# print = ("apple in fruits) # Returns true print("orange" in fruits) output: false
#
# String:
# greeting = print("hello" in greeting) and "hello world" # output: A true prints of the greeting "goodbye" # result: untrue
#
# Tuple:
# number = print(5, in numbers) = (1,2,3,4,5) # output: The true is to print with the numbers of 10 # Result: Not correct.
#
# dictionary:
#
# individual = {"name", "Stephen", "age":, 50}
# print(in person, "name") # result: true (keys checked).
# print(person.value() = > "Stephen").
