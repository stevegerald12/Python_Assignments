# %% [markdown]
# ### Steve Gerald

# %%
                                                             Assignment 2

# %% [markdown]
# ### 1) What is the difference between = and == in Python?
#
# In python, = and == are two distint operators with different purposes are
#
# *. = (Assignment Operator):
# -Assigns a value to a variable.
# - Example: x = 5 assigns the value 5 to the variable x.
# *. == (Equality Operator):
# -compares two values for equality.
# -Example: x == 5 checks if tghe value of x is equal to 5.
# * = is used to assign a value to a variable.
# * = is used to compare values for equality.
# Using = instead opf == in a comparison will result in a syntax error and using == instead of = in an assignment will not assign the value and will
# instead return a boolean value.
#
# x = 5 (correct assignment)
# x == 5 (correct comparison)
# x == 5 = True (incorrect, will not assign the value and will return a boolean value).

# %% [markdown]
# ### 2) How does the not operator work with boolean values?
#    The not operator in python is a logical operator that negates a boolean value.
#  * True if the boolean value is False
#  * False if the boolean value is True
#
# * Not True returns False
# * Not False returns True
# * Not (x > 5) returns True if x is not equal to 5 and False otherwise.
#
# The not Operator has a high precedence, so it's evaluated  before other logical operators like and, or. You can use parentheses to change the order of
# evaluation if needed.
#
# Not (x > 5) and y > 3 is equivalentr to (not ( x > 5) ) and Y > 3)

# %% [markdown]
# ## 3) Can you give an example of using the &amp; bitwise operator?
#
# The & bitwise operator in Python performs a bit by bit & operation between two integers
# x = 5 (binary: 101)
# y = 3 (Binary: 011)
# x and y (binary: 101 and 011 = 001) returns 1.
# In decimal
# 5 & 3 returns 1
#
# The & operator compares each bit of the first operand (x) to the corresponding bit of the second operand (y). If both bits are 1, the corresponding
# result bit is set to 1. otherwise, the result bit is set to 0.
#
# 101 (x) & 011 (y)
# -----
# 001 (result)
#
# This operation is useful in various scenarious such as
# * Checking if a specific bit is set in a binary number
# * Clearing specific bits in a binary number
# * Performing bitmasks anbd flags operations.

# %% [markdown]
# ### 4) How do you use the or logical operator in a condition?
#
# The or logical operator in python is used to combine two conditions in a way that if either of the conditions is true, the whole expression evaluates to
# true.
#
# Condition1 or condition2
#
# if condition1 is true, the expression evaluates to true without checking condition2. If condition1 is false, then condition2 is evaluated. If
# condition2 is true, the expression evaluates  to true; otherwise, it evaluates to false.
#
# x = 5
# y = 3
#
# if x > 2 or y > 2:
# Print("At least obe condition is true")
# has a lower precedence than and.
# if ( x > 2 or Y > 2) and z == 0.

# %% [markdown]
# ### 5) How do you use the is operator in Python?
#
# In python, this operator checks if two variables refer to the same object identity, not equality.
#
# * True if both variables point to the same object
# * False otherwise
#
# a = [1,2,3]
# b = [1,2,3]
# c = a
#
# print (a is b) # output: False (different objects)
# print (a is c) # output: True (same object)
#
# * Is checks for object identity, not equality. Even if two variables have the same value, they might not be the same object.
# * Is often used to check for None:
# - if x is none: (instead of if x == None:)
#
# * Use == for value euality checks
# * use is for object identity checks.

# %% [markdown]
# ### 6) What is the difference between is and == when comparing two strings in Python?
# In python, when comparing two string using is and == it happens.
# * == checks for value equality: It compares the actual string values charater by charater to see if they're the same.
# * is checks for object identity: It compares the memory addresses of the two strings to see if they're the same object.
#
# a = "Hello"
# b = "Hello"
#
# Print(a == b) # output: True (value equality)
# Print(a is b) # output: True (object identity, due to string interning)
#
# in this case, both == and is return True because python performs string interning, which means it stores only one copy of each unique string in memory.
#
# a = "Hello" + "world"
# b + "Hello" + "World"
#
# print(a == b) # output: True (value equality)
# Print(a is b) # output: false (different ojects)
#
# == still returns True because the values are equal, but is returns False because they're different objects in memory.
#
# * Use == to check if two strings have the same value.
# * Use is to check if two strings are the same object in memory(which is rarely necessary).

# %% [markdown]
# ### 7) Can you give an example of how the not in membership operator works?
#
# The not in membership operator in python checks if a value is not present in a sequence (such as a list, tuple, or string).
# fruits = ["apple", "banana", "cherry"]
#
# print("orange" not in fruits) # output: True
# Print("apple" not in fruits) # output: False
#
# * "orange" not in fruits returns True because "orange" is not in the fruits list.
# * "apple" not in fruits returns False because "apple" is in the fruits list.
#
# t = ("a", "b", "c")
# Print("d" not in t) # output:True
#
# S = "hello"
# Print("X" not in s) # output: True

# %% [markdown]
# ### 8) How do you use the &gt;= (greater than or equal to) comparison operator?
#
# The >= comparison operator in python checks if the value on the left is greater than or equal to the value on the right.
#
# Value1 >= value2
#
# Returns:
#
# * True if value1 is greater than or equal to value2
# * False otherwise
# eg
#
# * x = n5
# -x >= 5 returns True
# -x >= 3 returns True
# -x >= 7 returns False
#
# * y = 10
# -y >= 10 returns True
# -y >= 5 returns True
# -Y >= 15 returns False
#
# various data types with >= such as
#
# *Integers
# *Floats
# *String (compares lexicographically)
# *Dates and Times (Compares Chronologically).

# %% [markdown]
# ### 9) Can you show how to use the in membership operator?
#
# The in membership operator in python checks if a value is present in a sequence (such as a list, tuple, string, sequence( such as a list, tuple, string
# or dictionary).
#
# True if value is found in sequence
# False otherwise
#
# List:
#
# fruits = ["apple", "banana", "cherry"]
# Print("apple" in fruits) # Output: True
# Print("Orange" in fruits) # output: False
#
# Tuples:
#
# Colors = ("red", "green", "blue")
# Print("green" in colors) # output:True
# Print("yellow" in colors) # output: False
#
# Strings:
#
# S = "Hello World"
# Print("Hello" in s) # ouput: True
# Print("goodbye") in S) # output: False
#
# Dictionaries:
#
# Person = {"name": "john", "age": 30}
# Print("name" in person) # output: False.
